# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from kneed import KneeLocator

# %%
img = Image.open('Data_Problem_1_Sai_Thatigotla.jpg').convert('L')

# %%
plt.imshow(img, cmap='gray')

# %%
pic = np.array(img)

# %%
pic
# Out:
# array([[226, 226, 226, ..., 225, 225, 226],
#        [226, 226, 226, ..., 225, 226, 226],
#        [226, 226, 226, ..., 226, 226, 226],
#        ...,
#        [ 52,  54,  56, ...,  48,  47,  47],
#        [ 51,  54,  55, ...,  49,  49,  49],
#        [ 50,  53,  54, ...,  49,  49,  50]], dtype=uint8)

# %%
pic.shape
# Out:
# (3046, 1632)

# %%
u,s,v = np.linalg.svd(pic)

# %%
u.shape[1]
# Out:
# 3046

# %%
sigma = np.zeros((u.shape[1], v.shape[0]))
for i in range(min(u.shape[1], v.shape[0])):
    sigma[i, i] = s[i]

# %%
s.shape
# Out:
# (1632,)

# %%
sigma.shape
# Out:
# (3046, 1632)

# %%
v.shape
# Out:
# (1632, 1632)

# %%
u[:, 0:2].shape
# Out:
# (3046, 2)

# %%
v[0:2, :].shape
# Out:
# (2, 1632)

# %%
orig_size = (u.shape[0]*u.shape[1])+(sigma.shape[0]*sigma.shape[1]) + (v.shape[0] * v.shape[1])
print(orig_size)
# Out:
# 16912612

# %%
def compress(u, s, v, rank):
    new_sigma = np.zeros((u[:, 0:rank].shape[1], v[0:rank, :].shape[0]))
    for i in range(min(u[:, 0:rank].shape[1], v[0:rank, :].shape[0])):
        new_sigma[i, i] = s[i]
    new_img = np.dot(u[:, 0:rank], np.dot(new_sigma, v[0:rank, :]))
    size = (u[:, 0:rank].shape[0]*u[:, 0:rank].shape[1])+(new_sigma.shape[0]*new_sigma.shape[1]) + (v[0:rank, :].shape[0] * v[0:rank, :].shape[1])
    return size, new_img

# %%
ranks = [1, 5, 10, 20, 40, 80, 100, 150, 175, 200, 400, 500, 800, 1600]

# %%
nrows = int(len(ranks)/2)
fig, axes = plt.subplots(nrows, 2, figsize=(4,18))
i = 0
szs = []
for row in axes:
    sz,new_pic= compress(u, s, v, ranks[i])
    szs.append(sz)
    row[0].imshow(new_pic, cmap='gray')
    i += 1
    sz,new_pic= compress(u, s, v, ranks[i])
    szs.append(sz)
    row[1].imshow(new_pic, cmap='gray')
    i += 1
plt.show()

# %%
szs = np.array(szs)

# %%
szs.shape[0]
# Out:
# 14

# %%
test_ranks = np.arange(1, 1600, step=5)

# %%
vals = []
for i in test_ranks:
    sz,new_pic= compress(u, s, v, i)
    vals.append(sz)

# %%
vals
# Out:
# [4679,
#  28104,
#  51579,
#  75104,
#  98679,
#  122304,
#  145979,
#  169704,
#  193479,
#  217304,
#  241179,
#  265104,
#  289079,
#  313104,
#  337179,
#  361304,
#  385479,
#  409704,
#  433979,
#  458304,
#  482679,
#  507104,
#  531579,
#  556104,
#  580679,
#  605304,
#  629979,
#  654704,
#  679479,
#  704304,
#  729179,
#  754104,
#  779079,
#  804104,
#  829179,
#  854304,
#  879479,
#  904704,
#  929979,
#  955304,
#  980679,
#  1006104,
#  1031579,
#  1057104,
#  1082679,
#  1108304,
#  1133979,
#  1159704,
#  1185479,
#  1211304,
#  1237179,
#  1263104,
#  1289079,
#  1315104,
#  1341179,
#  1367304,
#  1393479,
#  1419704,
#  1445979,
#  1472304,
#  1498679,
#  1525104,
#  1551579,
#  1578104,
#  1604679,
#  1631304,
#  1657979,
#  1684704,
#  1711479,
#  1738304,
#  1765179,
#  1792104,
#  1819079,
#  1846104,
#  1873179,
#  1900304,
#  1927479,
#  1954704,
#  1981979,
#  2009304,
#  2036679,
#  2064104,
#  2091579,
#  2119104,
#  2146679,
#  2174304,
#  2201979,
#  2229704,
#  2257479,
#  2285304,
#  2313179,
#  2341104,
#  2369079,
#  2397104,
#  2425179,
#  2453304,
#  2481479,
#  2509704,
#  2537979,
#  2566304,
#  2594679,
#  2623104,
#  2651579,
#  2680104,
#  2708679,
#  2737304,
#  2765979,
#  2794704,
#  2823479,
#  2852304,
#  2881179,
#  2910104,
#  2939079,
#  2968104,
#  2997179,
#  3026304,
#  3055479,
#  3084704,
#  3113979,
#  3143304,
#  3172679,
#  3202104,
#  3231579,
#  3261104,
#  3290679,
#  3320304,
#  3349979,
#  3379704,
#  3409479,
#  3439304,
#  3469179,
#  3499104,
#  3529079,
#  3559104,
#  3589179,
#  3619304,
#  3649479,
#  3679704,
#  3709979,
#  3740304,
#  3770679,
#  3801104,
#  3831579,
#  3862104,
#  3892679,
#  3923304,
#  3953979,
#  3984704,
#  4015479,
#  4046304,
#  4077179,
#  4108104,
#  4139079,
#  4170104,
#  4201179,
#  4232304,
#  4263479,
#  4294704,
#  4325979,
#  4357304,
#  4388679,
#  4420104,
#  4451579,
#  4483104,
#  4514679,
#  4546304,
#  4577979,
#  4609704,
#  4641479,
#  4673304,
#  4705179,
#  4737104,
#  4769079,
#  4801104,
#  4833179,
#  4865304,
#  4897479,
#  4929704,
#  4961979,
#  4994304,
#  5026679,
#  5059104,
#  5091579,
#  5124104,
#  5156679,
#  5189304,
#  5221979,
#  5254704,
#  5287479,
#  5320304,
#  5353179,
#  5386104,
#  5419079,
#  5452104,
#  5485179,
#  5518304,
#  5551479,
#  5584704,
#  5617979,
#  5651304,
#  5684679,
#  5718104,
#  5751579,
#  5785104,
#  5818679,
#  5852304,
#  5885979,
#  5919704,
#  5953479,
#  5987304,
#  6021179,
#  6055104,
#  6089079,
#  6123104,
#  6157179,
#  6191304,
#  6225479,
#  6259704,
#  6293979,
#  6328304,
#  6362679,
#  6397104,
#  6431579,
#  6466104,
#  6500679,
#  6535304,
#  6569979,
#  6604704,
#  6639479,
#  6674304,
#  6709179,
#  6744104,
#  6779079,
#  6814104,
#  6849179,
#  6884304,
#  6919479,
#  6954704,
#  6989979,
#  7025304,
#  7060679,
#  7096104,
#  7131579,
#  7167104,
#  7202679,
#  7238304,
#  7273979,
#  7309704,
#  7345479,
#  7381304,
#  7417179,
#  7453104,
#  7489079,
#  7525104,
#  7561179,
#  7597304,
#  7633479,
#  7669704,
#  7705979,
#  7742304,
#  7778679,
#  7815104,
#  7851579,
#  7888104,
#  7924679,
#  7961304,
#  7997979,
#  8034704,
#  8071479,
#  8108304,
#  8145179,
#  8182104,
#  8219079,
#  8256104,
#  8293179,
#  8330304,
#  8367479,
#  8404704,
#  8441979,
#  8479304,
#  8516679,
#  8554104,
#  8591579,
#  8629104,
#  8666679,
#  8704304,
#  8741979,
#  8779704,
#  8817479,
#  8855304,
#  8893179,
#  8931104,
#  8969079,
#  9007104,
#  9045179,
#  9083304,
#  9121479,
#  9159704,
#  9197979,
#  9236304,
#  9274679,
#  9313104,
#  9351579,
#  9390104,
#  9428679,
#  9467304,
#  9505979,
#  9544704,
#  9583479,
#  9622304,
#  9661179,
#  9700104,
#  9739079,
#  9778104,
#  9817179,
#  9856304,
#  9895479,
#  9934704,
#  9973979,
#  10013304]

# %%
plt.figure(1, figsize=(20,10))
plt.plot(test_ranks, vals, marker='o', linestyle='--')
plt.title('Number of ranks kept vs number of bytes needed to store image', fontsize=20)
plt.grid()
plt.show()

# %%
kn = KneeLocator(np.array(ranks), szs, curve='convex', direction='increasing')
print(kn.knee)
# Out:
# 40
