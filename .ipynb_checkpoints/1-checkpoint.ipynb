# %%
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = Image.open('selfie.jpg').convert('L')

# %%
plt.imshow(img, cmap='gray')

# %%
pic = np.array(img)

# %%
pic
# Out:
# array([[225, 225, 225, ..., 225, 225, 226],
#        [225, 225, 225, ..., 225, 226, 226],
#        [225, 225, 225, ..., 226, 226, 226],
#        ...,
#        [ 52,  54,  56, ...,  48,  47,  47],
#        [ 51,  54,  55, ...,  49,  49,  49],
#        [ 50,  53,  54, ...,  49,  49,  50]], dtype=uint8)

# %%
pic.shape
# Out:
# (3046, 1632)

# %%
u,s,v = np.linalg.svd(pic)

# %%
u.shape[1]
# Out:
# 3046

# %%
sigma = np.zeros((u.shape[1], v.shape[0]))
for i in range(min(u.shape[1], v.shape[0])):
    sigma[i, i] = s[i]

# %%
s.shape
# Out:
# (1632, 1632)

# %%
sigma.shape
# Out:
# (3046, 1632)

# %%
v.shape
# Out:
# (1632, 1632)

# %%
u[:, 0:2].shape
# Out:
# (3046, 2)

# %%
v[0:2, :].shape
# Out:
# (2, 1632)

# %%
def compress(u, s, v, rank):
    new_sigma = np.zeros((u[:, 0:rank].shape[1], v[0:rank, :].shape[0]))
    for i in range(min(u.shape[1], v.shape[0])):
        new_sigma[i, i] = s[i]
    new_img = np.dot(u[:, 0:rank], np.dot(new_sigma, v[0:rank, :]))
    size = (u[:, 0:rank].shape[0]*2)+(new_sigma.shape[0]*new_sigma.shape[0]) + ()
